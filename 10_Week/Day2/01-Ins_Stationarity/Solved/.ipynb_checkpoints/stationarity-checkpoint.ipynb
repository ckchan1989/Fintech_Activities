# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import random
# %matplotlib inline

# %%
# Data Generation
# Warning! Boilerplate code
n = 100
x = np.arange(n)
y_stationary = np.random.normal(0, 1, n)

y_nonstationary = [random.random() + (x * .01) for x in range(100)]

# %%
type(y_stationary) #numpy Array
# Out:
# numpy.ndarray

# %%
y_stationary
# Out:
# array([-0.61846738, -0.50176158,  0.04228277, -0.14322788,  0.50258454,
#         1.56723247,  0.22696141,  0.21932788,  1.61972855, -0.10174124,
#         2.09740687, -0.50453458,  1.49179787,  0.41729617, -0.20014232,
#        -0.20651422, -0.85888557, -0.19047878, -0.56025726,  1.03224678,
#         0.79067605,  1.12716917,  0.91835713,  0.0408167 ,  1.78614098,
#        -0.0051067 , -0.46141375, -0.38839993, -0.3790379 , -0.00923685,
#         1.07259253, -0.1653189 , -1.09736271,  0.40639173, -0.11185258,
#         0.19299268,  0.05108321,  1.34236025, -1.13219739,  1.30184733,
#         1.62684399,  0.62933536, -0.38556787, -0.13283533,  0.80319386,
#        -1.30155371, -1.03003991, -0.48632205,  0.2010218 , -0.90138657,
#        -1.06792005, -0.10863662,  1.0283903 , -0.40832311,  0.39432814,
#         0.92488105, -0.44328069,  0.54582173, -0.37423169,  0.35652422,
#        -0.26161059, -0.97151487, -0.47576442, -1.27453595,  0.85739266,
#         1.51198563, -2.50489895, -0.95986254, -0.06753373,  0.30549908,
#        -0.19881848, -0.19300796, -0.21655973,  0.49441038, -0.13279689,
#        -0.59195993, -0.73773982,  1.08224626, -0.57268453,  1.12004064,
#        -0.61917043, -0.50543473, -0.94838985,  0.00600206,  0.76035562,
#        -1.51636115,  2.17885945, -0.5170119 , -0.02322838,  0.70114698,
#        -0.77276096, -0.49006891, -0.9111596 ,  0.31162971,  1.66786281,
#         0.88021759,  0.33257861,  0.56423736,  0.51342968,  0.28524025])

# %%
#slice the data from numpy array 
y_stationary[0:2]
# Out:
# array([-0.61846738, -0.50176158])

# %%
#convert numpy array into dataframe
df_fromArray = pd.DataFrame(y_stationary, columns = ['Column_A'])
df_fromArray.head(2)
# Out:
#    Column_A
# 0 -0.618467
# 1 -0.501762

# %%
type(y_nonstationary)
# Out:
# list

# %%
y_nonstationary[:2]
# Out:
# [0.1932090875764393, 0.7820119776725282]

# %%
df = pd.DataFrame({
    "Stationary": y_stationary,
    "Nonstationary": y_nonstationary
})

df.head(2)
# Out:
#    Stationary  Nonstationary
# 0   -0.618467       0.193209
# 1   -0.501762       0.782012

# %%
# Plot the stationary data
df.Stationary.plot()
# Out:
# <AxesSubplot:>

# %%
# Plot the non-stationary data
df.Nonstationary.plot()
# Out:
# <AxesSubplot:>

# %%
boxplot = df.boxplot(grid=True, rot=45, fontsize=15, column=['Stationary', 'Nonstationary'], showmeans=True)

# %%
# Apply the Augmented Dickey-Fuller test to determine if the above is stationary
from statsmodels.tsa.stattools import adfuller
adfuller(df.Stationary)
# Out:
# (-10.163339201243518,
#  7.408590445231663e-18,
#  0,
#  99,
#  {'1%': -3.498198082189098,
#   '5%': -2.891208211860468,
#   '10%': -2.5825959973472097},
#  220.29976859828048)

# %%
# Compare the Augmented Dickey-Fuller test to non-stationary data
adfuller(df.Nonstationary)
# Out:
# (-1.5460865163428619,
#  0.5106024360969741,
#  9,
#  90,
#  {'1%': -3.505190196159122,
#   '5%': -2.894232085048011,
#   '10%': -2.5842101234567902},
#  46.730146716806075)

# %% [markdown]
# # Non-Stationary to Stationary Techniques

# %% [markdown]
# ### Technique 1: Applying a Percent Change

# %%
# Convert to stationary data by taking the `pct_change` of the non-stationary data.
df['Returns'] = df.Nonstationary.pct_change()

# %%
# Drop the NaNs created by the pct_change function
df = df.dropna()

# %%
# Plot the returns as a line chart. 
# You should no longer see the upward trend in the data
df.Returns.plot()
# Out:
# <AxesSubplot:>

# %%
df.Nonstationary.plot()
# Out:
# <AxesSubplot:>

# %%
adfuller(df.Returns)
# Out:
# (-14.0973812800762,
#  2.655607653528544e-26,
#  0,
#  97,
#  {'1%': -3.4996365338407074,
#   '5%': -2.8918307730370025,
#   '10%': -2.5829283377617176},
#  132.7559722037662)

# %% [markdown]
# ### Technique 2: Applying a Diff

# %%
# Subtract the upward trend for the non-stationary data using the `diff()` function
df['Diff'] = df.Nonstationary.diff()

# %%
# Drop the NaNs created from the diff function
df = df.dropna()

# %%
# Plot the data
df.Diff.plot()
# Out:
# <AxesSubplot:>

# %%
df.Nonstationary.plot()
# Out:
# <AxesSubplot:>

# %%
adfuller(df.Diff)
# Out:
# (-8.82131119252839,
#  1.8740221450273022e-14,
#  3,
#  94,
#  {'1%': -3.5019123847798657,
#   '5%': -2.892815255482889,
#   '10%': -2.583453861475781},
#  45.12052214101803)
