# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
# Read CSV, parse dates, and set index
csvpath = Path('../Resources/euro_cad.csv')
df = pd.read_csv(csvpath, parse_dates=True, index_col='Date')
df.head(2)
# Out:
#                         Rate
# Date
# 2014-01-01 23:58:00  1.46520
# 2014-01-02 23:58:00  1.45779

# %%
# Daily EUR to CAD exchange rates
df.Rate.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Daily percentage changes in exchange rate (resampled to daily)
df['Return'] = df.Rate.pct_change() * 100 * 24
df = df.resample('D').mean()
df = df.dropna()
df.head()
# Out:
#                Rate     Return
# Date
# 2014-01-02  1.45779 -12.137592
# 2014-01-03  1.44500 -21.056531
# 2014-01-04  1.44500   0.000000
# 2014-01-05  1.44540   0.664360
# 2014-01-06  1.45290  12.453300

# %%
# Plot returns
df.Return.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # GARCH

# %%
df.head()
# Out:
#                Rate     Return
# Date
# 2014-01-02  1.45779 -12.137592
# 2014-01-03  1.44500 -21.056531
# 2014-01-04  1.44500   0.000000
# 2014-01-05  1.44540   0.664360
# 2014-01-06  1.45290  12.453300

# %%
# Create the GARCH model
from arch import arch_model
model = arch_model(df.Return, mean="Zero", vol="GARCH", p=2, q=2)

# %%
res = model.fit(disp="on")
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 13036018.207707448
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 7564.982099719939
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 7592.769854830252
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 8017.018301305615
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 353648030.72011477
# Iteration:      6,   Func. Count:     46,   Neg. LLF: 7926.381099059867
# Iteration:      7,   Func. Count:     53,   Neg. LLF: 7562.98895496832
# Iteration:      8,   Func. Count:     60,   Neg. LLF: 7558.62402271613
# Iteration:      9,   Func. Count:     66,   Neg. LLF: 7558.416209485828
# Iteration:     10,   Func. Count:     72,   Neg. LLF: 7558.593221828344
# Iteration:     11,   Func. Count:     79,   Neg. LLF: 7559.99345258644
# Iteration:     12,   Func. Count:     86,   Neg. LLF: 7558.122626402972
# Iteration:     13,   Func. Count:     92,   Neg. LLF: 7558.124248251168
# Iteration:     14,   Func. Count:     99,   Neg. LLF: 7558.120945363854
# Iteration:     15,   Func. Count:    105,   Neg. LLF: 7558.120943563496
# Iteration:     16,   Func. Count:    110,   Neg. LLF: 7558.120943560058

# %%
# Output the model summary
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -7558.12
# Distribution:                  Normal   AIC:                           15126.2
# Method:            Maximum Likelihood   BIC:                           15154.3
#                                         No. Observations:                 2005
# Date:                Mon, Apr 19 2021   Df Residuals:                     2005
# Time:                        21:43:31   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          1.0575      0.745      1.419      0.156      [ -0.404,  2.518]
# alpha[1]       0.0527  1.399e-02      3.767  1.650e-04  [2.529e-02,8.014e-02]
# alpha[2]       0.0000  1.159e-02      0.000      1.000 [-2.271e-02,2.271e-02]
# beta[1]    5.7134e-03  2.663e-02      0.215      0.830 [-4.649e-02,5.792e-02]
# beta[2]        0.9329  2.788e-02     33.464 1.600e-245      [  0.878,  0.988]
# =============================================================================
#
# Covariance estimator: robust
# """

# %%
# Plot the model estimate of the annualized volatility
fig = res.plot(annualize='D')

# %% [markdown]
# # Forecasting from GARCH

# %%
# Find the last day of the dataset
last_day = df.index.max().strftime('%Y-%m-%d')
last_day
# Out:
# '2019-08-23'

# %%
# Create a 5 day forecast of EUR to CAD exchange rate volatility
forecast_horizon = 5

# Take the last day of the data we used above. 
# If forecast horizon is 3, then the resulting 'h.1', 'h.2', and 'h.3' 
# are the forecasts for the following 3 days.
forecasts = res.forecast(start=last_day, horizon=forecast_horizon)
forecasts
# Out:
# C:\Users\Chris Chan\anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
# Annualize the forecast
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate
# Out:
#                    h.1         h.2         h.3         h.4         h.5
# Date
# 2019-08-23  137.271142  123.033147  136.856839  124.427543  136.543054

# %% [markdown]
# # Visualizing the forecast

# %%
# Transpose the forecast so that it is easier to plot
final = intermediate.dropna().T
final.head()
# Out:
# Date  2019-08-23
# h.1   137.271142
# h.2   123.033147
# h.3   136.856839
# h.4   124.427543
# h.5   136.543054

# %%
# Plot the final forecast
final.plot()
# Out:
# <AxesSubplot:>
