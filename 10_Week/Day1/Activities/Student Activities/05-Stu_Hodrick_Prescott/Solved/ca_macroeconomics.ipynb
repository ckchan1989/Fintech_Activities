# %% [markdown]
# # CA Macroeconomics

# %%
# Import libraries and dependencies
import pandas as pd
import datetime
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Hodrick-Prescott filter analysis

# %% [markdown]
# ### GDP Analysis

# %%
# Read the GDP csv data and set the column `DATE` as a datetime index
file_path = Path("../Resources/ca_gdp_data.csv")
gdp = pd.read_csv(file_path, index_col='DATE', infer_datetime_format=True, parse_dates=True)
gdp.head()
# Out:
#                      GDP
# DATE
# 2004-01-01  392000000000
# 2004-04-01  396000000000
# 2004-07-01  401000000000
# 2004-10-01  404000000000
# 2005-01-01  405000000000

# %%
# Plot the raw GDP data as a line plot
gdp.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Use the `hpfilter` function to decompose the GDP column into the trend and noise components.
import statsmodels.api as sm
gdp_noise, gdp_trend = sm.tsa.filters.hpfilter(gdp["GDP"])

# %%
# Plot the GDP trend data as a line plot
gdp_trend.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Plot the GDP noise data as a line plot
gdp_noise.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ---

# %% [markdown]
# ### Inflation

# %%
# Read the Inflation csv data and set the column `DATE` as a datetime index
# Note: Inflation, as measured by consumer price index in urban areas
file_path = Path("../Resources/ca_inflation.csv")
inflation = pd.read_csv(file_path, index_col='DATE', infer_datetime_format=True, parse_dates=True)
inflation.head()
# Out:
#             INFLATION_RATE
# DATE
# 2004-01-01        1.857259
# 2005-01-01        2.213552
# 2006-01-01        2.002025
# 2007-01-01        2.138384
# 2008-01-01        2.370271

# %%
# Plot the raw inflation data as a line plot
inflation.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Use the `hpfilter` function to decompose the `INFLATION_RATE` column into the trend and noise components.
inflation_noise, inflation_trend = sm.tsa.filters.hpfilter(inflation['INFLATION_RATE'])

# %%
# Plot the inflation trend data as a line plot
inflation_trend.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Plot the inflation noise data as a line plot
inflation_noise.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Plot the exponentially-weighted moving average for the inflation data
inflation['INFLATION_RATE'].ewm(halflife=6).mean().plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ---

# %% [markdown]
# ### Job Data

# %%
# Read the Employment csv data and set the column `DATE` as a datetime index
# Note: This is the total number of non-farm payrolls
file_path = Path("../Resources/ca_employment.csv")
job_roll = pd.read_csv(file_path, index_col='DATE', infer_datetime_format=True, parse_dates=True)
job_roll.head()
# Out:
#             EMPLOYMENT_RATE
# DATE
# 2004-01-01             81.2
# 2004-02-01             81.3
# 2004-03-01             81.4
# 2004-04-01             81.5
# 2004-05-01             81.5

# %%
# Plot the raw job data as a line plot
job_roll.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Use the `hpfilter` function to decompose the `EMPLOYMENT_RATE` column into the trend and noise components.
job_roll_noise, job_roll_trend = sm.tsa.filters.hpfilter(job_roll['EMPLOYMENT_RATE'])

# %%
# Plot the job trend data as a line plot
job_roll_trend.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Plot the job noise data as a line plot
job_roll_noise.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Plot the exponentially-weighted moving average for the job data
job_roll['EMPLOYMENT_RATE'].ewm(halflife=6).mean().plot()
# Out:
# <AxesSubplot:xlabel='DATE'>
