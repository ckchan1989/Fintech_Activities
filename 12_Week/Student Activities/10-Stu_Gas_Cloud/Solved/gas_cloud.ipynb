# %% [markdown]
# # Gas Cloud
# In this activity you will create your own word clouds using a subset of the Reuters corpus.

# %%
from nltk.corpus import stopwords, reuters
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt

# Code to download wordnet corpora
import nltk
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /usr/local/Caskroom/miniconda/base/envs/pyvizenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pankajkumar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Get reuters stories where categories='gas'
ids = reuters.fileids(categories='gas')
corpus = [reuters.raw(i) for i in ids]
len(corpus)
# Out:
# 54

# %%
corpus[:2]
# Out:
# ["FINNS AND CANADIANS TO STUDY MTBE PRODUCTION PLANT\n  Finland's national oil company Neste Oy\n  &lt;NEOY.HE> said in a statement it had agreed with Canadian firms\n  to study the feasibility of building a plant in Edmonton,\n  Canada, to produce a replacement for lead in petrol.\n      The prospective plant would cost an estimated 270 mln\n  Canadian dlrs and would produce methyl tertiary butyl ether\n  (MTBE) from raw materials available locally, it said.\n      The partners in the study are Neste Oy, Celanese Canada\n  Inc, Hoechst Celanese Corporation and Trade Mountain Pipe Line\n  Company Ltd, of Vancouver, B.C.\n      The Edmonton site was suitable because of the raw materials\n  availability, the proximity to pipeline transportation and the\n  important capital and operating advantages gained by locating\n  on an existing Celanese Canada site, the statement said.\n      The partners would look into the feasibility of a plant\n  producing 500,000 tonnes per annum of MTBE, an octane enhancer\n  that can replace tetra ethyl lead.\n      Most of the MTBE would be targeted for the United States\n  where lead levels in gasoline are being lowered because of\n  health concerns, the statement added.\n      Canadian lead limits are currently 11 times as high as the\n  U.S. Limit but lead is scheduled for virtual elimination in\n  Canada by 1993, which should create a Canadian demand for MTBE,\n  it said.\n      Finland's Neste Oy, whose turnover last year was over five\n  billion dlrs, has extensive experience with MTBE. It has a\n  major investment in an MTBE plant in Saudi Arabia.\n      The Edmonton, Alberta plant would be scheduled to go on\n  stream in late 1989, the statement said.\n  \n\n",
#  'EIA SAYS DISTILLATE STOCKS UNCHANGED, GASOLINE OFF 200,000, CRUDE UP 6.3 MLN\n\n  EIA SAYS DISTILLATE STOCKS UNCHANGED, GASOLINE OFF 200,000, CRUDE UP 6.3 MLN\n  \n\n']

# %%
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

# %%
# Process text for wordcloud creation
big_string = ' '.join(corpus)
input_words = process_text(big_string)
input_words
# Out:
# 'finns canadians study mtbe production plant finlands national oil company neste oy ltneoyhe said statement agreed canadian firm study feasibility building plant edmonton canada produce replacement lead petrol prospective plant would cost estimated mln canadian dlrs would produce methyl tertiary butyl ether mtbe raw material available locally said partner study neste oy celanese canada inc hoechst celanese corporation trade mountain pipe line company ltd vancouver bc edmonton site wa suitable raw material availability proximity pipeline transportation important capital operating advantage gained locating existing celanese canada site statement said partner would look feasibility plant producing tonne per annum mtbe octane enhancer replace tetra ethyl lead mtbe would targeted united states lead level gasoline lowered health concern statement added canadian lead limit currently time high us limit lead scheduled virtual elimination canada create canadian demand mtbe said finlands neste oy whose turnover last year wa five billion dlrs ha extensive experience mtbe ha major investment mtbe plant saudi arabia edmonton alberta plant would scheduled go stream late statement said eia says distillate stocks unchanged gasoline crude mln eia says distillate stocks unchanged gasoline crude mln eia says distillate stocks unchanged week distillate fuel stock held primary storage unchanged week ended april three mln barrel energy information administration eia said weekly petroleum status report department energy agency said gasoline stock barrel week mln barrel refinery crude oil stock rose mln barrel mln eia said residual fuel stock fell barrel mln barrel crude oil stock strategic petroleum reserve spr rose mln barrel mln total crude refined product spr stock rose mln barrel said recent us oil demand pct year ago us oil demand measured product supplied fell pct four week ended april three mln barrel per day bpd mln period year ago energy information administration eia said weekly petroleum status report energy department agency said distillate demand wa pct period mln bpd mln year earlier gasoline demand averaged mln bpd pct mln last year residual fuel demand wa mln bpd pct mln eia said far year distillate demand fell pct mln bpd mln gasoline demand wa mln bpd pct mln residual fuel demand fell pct mln bpd mln eia said yeartodate domestic crude output wa estimated mln bpd pct mln year ago gross crude import averaged mln bpd pct mln said exxon ltxon extends midgrade unleaded marketing exxon co usa said expanding marketing midgrade unleaded gasoline along us east coast exxon corp subsidiary said changeover octane unleaded fuel begin late month early next major market virginia maryland florida district columbia product wa introduced new york new jersey delaware connecticut rhode island massachusetts new hampshire philadelphia area late last year singapore oil companies set pump prices singapore oil company set petrol diesel price pump today subject ceiling determined individual wholesale price ministry trade industry said ministry previously revised pump price announced change oil company lead content petrol cut gmlitre gm today pump price lower lead petrol grade expected announced soon oil company said wholesale price centslitre cent higher previous grade singapore petroleum co revises petrol pump prices singapore petroleum co pte ltd revise pump price petrol june official said grade octane gmlead centslitre cent previously gm lead grade octane cent previously spcs price revision follows ministry trade industrys move liberalise petrol pricing allowing oil company set pump price new grade petrol lower lead content sold singapore today line ministry environments regulation mobil raises singapore petrol pump prices mobil oil singapore pte lte raise pump price petrol june spokeswoman said grade octane gm lead centslitre cent previously gm lead grade octane cent previously spc earlier announced pump price cent cent octane respectively gm lead petrol ...

# %%
# Generate wordcloud
wc = WordCloud().generate(input_words)
plt.imshow(wc)

# %% [markdown]
# ## Challenge

# %%
from nltk.util import ngrams

# %%
def process_text_bg(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    sw_words = [word.lower() for word in lem if word.lower() not in sw]
    bigrams = ngrams(sw_words, 2)
    output = ['_'.join(i) for i in bigrams]
    return ' '.join(output)

# %%
# Process text for wordcloud creation
input_bigrams = process_text_bg(big_string)
input_bigrams
# Out:
# 'finns_canadians canadians_study study_mtbe mtbe_production production_plant plant_finlands finlands_national national_oil oil_company company_neste neste_oy oy_ltneoyhe ltneoyhe_said said_statement statement_agreed agreed_canadian canadian_firm firm_study study_feasibility feasibility_building building_plant plant_edmonton edmonton_canada canada_produce produce_replacement replacement_lead lead_petrol petrol_prospective prospective_plant plant_would would_cost cost_estimated estimated_mln mln_canadian canadian_dlrs dlrs_would would_produce produce_methyl methyl_tertiary tertiary_butyl butyl_ether ether_mtbe mtbe_raw raw_material material_available available_locally locally_said said_partner partner_study study_neste neste_oy oy_celanese celanese_canada canada_inc inc_hoechst hoechst_celanese celanese_corporation corporation_trade trade_mountain mountain_pipe pipe_line line_company company_ltd ltd_vancouver vancouver_bc bc_edmonton edmonton_site site_wa wa_suitable suitable_raw raw_material material_availability availability_proximity proximity_pipeline pipeline_transportation transportation_important important_capital capital_operating operating_advantage advantage_gained gained_locating locating_existing existing_celanese celanese_canada canada_site site_statement statement_said said_partner partner_would would_look look_feasibility feasibility_plant plant_producing producing_tonne tonne_per per_annum annum_mtbe mtbe_octane octane_enhancer enhancer_replace replace_tetra tetra_ethyl ethyl_lead lead_mtbe mtbe_would would_targeted targeted_united united_states states_lead lead_level level_gasoline gasoline_lowered lowered_health health_concern concern_statement statement_added added_canadian canadian_lead lead_limit limit_currently currently_time time_high high_us us_limit limit_lead lead_scheduled scheduled_virtual virtual_elimination elimination_canada canada_create create_canadian canadian_demand demand_mtbe mtbe_said said_finlands finlands_neste neste_oy oy_whose whose_turnover turnover_last last_year year_wa wa_five five_billion billion_dlrs dlrs_ha ha_extensive extensive_experience experience_mtbe mtbe_ha ha_major major_investment investment_mtbe mtbe_plant plant_saudi saudi_arabia arabia_edmonton edmonton_alberta alberta_plant plant_would would_scheduled scheduled_go go_stream stream_late late_statement statement_said said_eia eia_says says_distillate distillate_stocks stocks_unchanged unchanged_gasoline gasoline_crude crude_mln mln_eia eia_says says_distillate distillate_stocks stocks_unchanged unchanged_gasoline gasoline_crude crude_mln mln_eia eia_says says_distillate distillate_stocks stocks_unchanged unchanged_week week_distillate distillate_fuel fuel_stock stock_held held_primary primary_storage storage_unchanged unchanged_week week_ended ended_april april_three three_mln mln_barrel barrel_energy energy_information information_administration administration_eia eia_said said_weekly weekly_petroleum petroleum_status status_report report_department department_energy energy_agency agency_said said_gasoline gasoline_stock stock_barrel barrel_week week_mln mln_barrel barrel_refinery refinery_crude crude_oil oil_stock stock_rose rose_mln mln_barrel barrel_mln mln_eia eia_said said_residual residual_fuel fuel_stock stock_fell fell_barrel barrel_mln mln_barrel barrel_crude crude_oil oil_stock stock_strategic strategic_petroleum petroleum_reserve reserve_spr spr_rose rose_mln mln_barrel barrel_mln mln_total total_crude crude_refined refined_product product_spr spr_stock stock_rose rose_mln mln_barrel barrel_said said_recent recent_us us_oil oil_demand demand_pct pct_year year_ago ago_us us_oil oil_demand demand_measured measured_product product_supplied supplied_fell fell_pct pct_four four_week week_ended ended_april april_three three_mln mln_barrel barrel_per per_day day_bpd bpd_mln mln_period period_year year_ago ago_energy energy_information information_administration administration_eia eia_said said_weekly weekly_petrole ...

# %%
# Generate wordcloud
wc = WordCloud().generate(input_bigrams)
plt.imshow(wc)
